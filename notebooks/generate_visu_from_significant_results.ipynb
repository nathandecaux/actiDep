# %%
import os
from tractviewer import TractViewer
from actiDep.data.loader import Actidep
from actiDep.set_config import get_HCP_bundle_names
NO_ACTI_CSV = "/home/ndecaux/report_optimized_no_actimetry_clusterFWE/summary_results.csv"
import pandas as pd

# Tracts fronto-limbiques MANQUE SLFII
fronto_limbiques = [
    "CG_left", "CG_right",
    "UF_left", "UF_right",
    "FX_left", "FX_right",
    "FPT_left", "FPT_right",
    "T_PREF_left", "T_PREF_right",
    "ST_FO_left", "ST_FO_right",
    "ST_PREF_left", "ST_PREF_right"
]

renaud_dep_controls = ['ATR', 'CC1','SLFI','SLFIII','STPREM', 'UF']
renaud_apathy = ['CC1','CC2','CST','SLFIII','STPREM']

to_remove = []
for b in renaud_dep_controls:
    if b+'right' in list(get_HCP_bundle_names().keys()):
        renaud_dep_controls.append(b+'left')
        renaud_dep_controls.append(b+'right')
        to_remove.append(b)

renaud_dep_controls= [b for b in renaud_dep_controls if b not in to_remove]

for b in renaud_apathy:
    if b+'right' in list(get_HCP_bundle_names().keys()):
        renaud_apathy.append(b+'left')
        renaud_apathy.append(b+'right')
        to_remove.append(b)
renaud_apathy= [b for b in renaud_apathy if b not in to_remove]


# ST_PREM CC2 CC_3
# Tracts associés aux émotions
emotions = [
    "CG_left", "CG_right",
    "UF_left", "UF_right",
    "FX_left", "FX_right",
    "ATR_left", "ATR_right",
    "CA",
    "T_PREF_left", "T_PREF_right",
    "ST_FO_left", "ST_FO_right",
    "ST_PREF_left", "ST_PREF_right"
]

# Tracts moteurs
moteurs = [
    "CST_left", "CST_right",
    "CC_3", "CC_4",
    "T_PREM_left", "T_PREM_right",
    "T_PREC_left", "T_PREC_right",
    "T_POSTC_left", "T_POSTC_right",
    "ST_PREM_left", "ST_PREM_right",
    "ST_PREC_left", "ST_PREC_right",
    "ST_POSTC_left", "ST_POSTC_right",
    "ICP_left", "ICP_right",
    "MCP",
    "SCP_left", "SCP_right"
]

fronto_limbiques=[b.replace('_','') for b in fronto_limbiques]
emotions=[b.replace('_','') for b in emotions]
moteurs=[b.replace('_','') for b in moteurs]

df=pd.read_csv(NO_ACTI_CSV)
filters={
    "fronto_limbiques": df['bundle'].isin(fronto_limbiques),
    "emotions": df['bundle'].isin(emotions),
    "moteurs": df['bundle'].isin(moteurs),
    "significant": df['n_sig_corrected'] > 0,
    "all_subs": df['removed_subjects']<2,
    "all_points": df['removed_points']<4,
    "metric": df['metric'].isin(['FA','IFW','IRF'])
}

#Application de tous les filtres
final_filter = filters["significant"] & filters["all_subs"] & filters["all_points"] & (filters["emotions"] | filters["moteurs"] | filters["fronto_limbiques"]) & filters["metric"]
df_filtered = df[final_filter]
df_filtered
# Out:
#             bundle metric          type  n_sig_raw  n_sig_corrected  \
# 95        STFOleft     FA   group_group          2                2
# 101      STFOright     FA   group_group          2                1
# 126     TPREMright     FA   group_group          0                1
# 130     STPREFleft     FA   group_group          1                1
# 138         UFleft     FA   group_group          1                1
# 153        FPTleft    IFW   group_group          1                1
# 166       STFOleft    IFW   group_group          1                1
# 170            CC4    IFW   group_group          1                1
# 172      STFOright    IFW   group_group          1                1
# 180     STPREMleft    IFW   group_group          1                1
# 185   STPOSTCright    IFW   group_group          1                1
# 197     TPREMright    IFW   group_group          1                1
# 201     STPREFleft    IFW   group_group          1                1
# 209         UFleft    IFW   group_group          1                1
# 219        CSTleft    IRF   group_group          0                1
# 243      STFOright    IRF   group_group          1                1
# 258    STPOSTCleft    IRF   group_group          1                1
# 261     STPRECleft    IRF   group_group          0                1
# 265     TPOSTCleft    IRF   group_group          1                1
# 279      TPRECleft    IRF   group_group          0                1
# 644       CSTright    IRF  group_apathy          0                1
# 684    STPOSTCleft    IRF  group_apathy          0                1
# 999       STFOleft    IRF      corr_ami          0                1
# 1081    STPREMleft     FA      corr_ami          1                1
# 1351      FPTright     FA      corr_aes          1                1
# 1353      FPTright    IRF      corr_aes          0                1
# 1423      STFOleft     FA      corr_aes          0                1
# 1461     STFOright    IRF      corr_aes          0                1
# 1507    STPREMleft     FA      corr_aes          1                2
# 1508    STPREMleft    IFW      corr_aes          0                1
# 1539  STPOSTCright    IRF      corr_aes          0                1
# 1550   STPOSTCleft    IFW      corr_aes          0                1
# 1563   STPRECright    IRF      corr_aes          0                2
# 1567    STPRECleft     FA      corr_aes          1                1
# 1568    STPRECleft    IFW      corr_aes          0                2
# 1592    TPOSTCleft    IFW      corr_aes          0                1
# 1627   STPREFright     FA      corr_aes          1                1
# 1629   STPREFright    IRF      corr_aes          0                1
# 1633    STPREFleft     FA      corr_aes          0                1
# 1639    TPREFright     FA      corr_aes          1                1
# 1641    TPREFright    IRF      corr_aes          0                1
# 1676     TPRECleft    IFW      corr_aes          0                1
# 1681        UFleft     FA      corr_aes          0                1
#
#       min_p_raw  min_p_corrected  max_abs_r_raw  max_abs_r_partial  \
# 95     0.000257         0.000378            NaN                NaN
# 101    0.007571         0.005636            NaN                NaN
# 126    0.005899         0.002610            NaN                NaN
# 130    0.006054         0.005968            NaN                NaN
# 138    0.003240         0.001302            NaN                NaN
# 153    0.002281         0.004969            NaN                NaN
# 166    0.000924         0.001519            NaN                NaN
# 170    0.015762         0.032534            NaN                NaN
# 172    0.002986         0.005035            NaN                NaN
# 180    0.011904         0.013744            NaN                NaN
# 185    0.000069         0.000123            NaN                NaN
# 197    0.002131         0.000997            NaN                NaN
# 201    0.000587         0.000466            NaN                NaN
# 209    0.005493         0.003445            NaN                NaN
# 219    0.015888         0.003843            NaN                NaN
# 243    0.002239         0.002816            NaN                NaN
# 258    0.003469         0.002191            NaN                NaN
# 261    0.006150         0.001589            NaN                NaN
# 265    0.000795         0.000974            NaN                NaN
# 279    0.016056         0.011693            NaN                NaN
# 644    0.008866         0.003954            NaN                NaN
# 684    0.002915         0.000835            NaN                NaN
# 999    0.010929         0.008641       0.437319           0.449743
# 1081   0.000059         0.000182       0.640632           0.606747
# 1351   0.003748         0.005889       0.490593           0.469105
# 1353   0.023489         0.000815       0.393465           0.554361
# 1423   0.008468         0.007997       0.444356           0.447275
# 1461   0.017098         0.003810       0.406332           0.483010
# 1507   0.001313         0.000666       0.528512           0.554534
# 1508   0.031940         0.016757       0.368615           0.407482
# 1539   0.012517         0.000560       0.423725           0.560873
# 1550   0.012805         0.003593       0.422488           0.485687
# 1563   0.021412         0.000078       0.393219           0.624947
# 1567   0.001224         0.010642       0.531310           0.432442
# 1568   0.024274         0.003530       0.385687           0.486481
# 1592   0.024168         0.005359       0.385953           0.467027
# 1627   0.000178         0.004108       0.599768           0.479543
# 1629   0.101250         0.000468       0.285849           0.567263
# 1633   0.014650         0.001647       0.415059           0.519340
# 1639   0.005861         0.006818       0.462706           0.455284
# 1641   0.014204         0.000045       0.416782           0.640811
# 1676   0.055948         0.007344       0.330885           0.451578
# 1681   0.028807         0.010266       0.380771           0.440672
#
#       removed_subjects  removed_points  clusterFWE_raw  clusterFWE_corrected
# 95                   0               2             8.0                   9.0
# 101                  0               2             8.0                   8.0
# 126                  0               2             7.0                   6.0
# 130                  0               2            10.0                  10.0
# 138                  1               2             6.0                   6.0
# 153                  0               2             7.0                   7.0
# 166                  0               2            10.0                  10.0
# 170                  1               2             6.0                   6.0
# 172                  0               2            10.0                   9.0
# 180                  0               2            11.0                  12.0
# 185                  0               2            10.0                  10.0
# 197                  0               2             8.0                   8.0
# 201                  0               2            13.0                  12.0
# 209                  1               2             6.0                   6.0
# 219                  1               2             5.0                   5.0
# 243                  0               2             9.0                   8.0
# 258                  0               2             9.0                   9.0
# 261                  0               2             9.0                   9.0
# 265                  0               2             8.0                   8.0
# 279                  0               2             8.0                   8.0
# 644                  1               2             5.0                   5.0
# 684                  0               2             9.0                   9.0
# 999                  0               2             9.0                   8.0
# 1081                 0               2            10.0                  10.0
# 1351                 1               2             6.0                   7.0
# 1353                 1               2             6.0                   6.0
# 1423                 0               2             7.0                   7.0
# 1461                 0               2            10.0                   9.0
# 1507                 0               2             9.0                  10.0
# 1508                 0               2            13.0                  13.0
# 1539                 0               2             8.0                   8.0
# 1550                 0               2            12.0                  12.0
# 1563                 0               2             9.0                   9.0
# 1567                 0               2            11.0                  10.0
# 1568                 0               2            13.0                  13.0
# 1592                 0               2            10.0                  10.0
# 1627                 0               2            11.0                   9.0
# 1629                 0               2            10.0                  11.0
# 1633                 0               2            10.0                  11.0
# 1639                 0               2             8.0                   7.0
# 1641                 0               2             7.0                   7.0
# 1676                 0               2            12.0                  11.0
# 1681                 1               2             6.0                   5.0

# %%
# df_acti_filtered['val']=df_acti_filtered['type'].apply(lambda x: x.split('_')[0])
# df_acti_filtered['val']=df_acti_filtered['type'].apply(lambda x: x.split('_')[1])
df_filtered['val']=df_filtered['type'].apply(lambda x: x.split('_')[1])
df_filtered['type']=df_filtered['type'].apply(lambda x: x.split('_')[0])
df_filtered['csv']=df_filtered.apply(lambda row: os.path.join(os.path.dirname(NO_ACTI_CSV), 'figures', f"{row['bundle']}_{row['metric']}_{row['val']}_{row['type']}_{'corrected' if 'group' in row['type'] else "partial"}.csv"), axis=1)
df_filtered['png']=df_filtered.apply(lambda row: os.path.join(os.path.dirname(NO_ACTI_CSV), 'figures', f"{row['bundle']}_{row['metric']}_{row['val']}_{row['type']}_{'corrected' if 'group' in row['type'] else "partial"}.png"), axis=1)
# Out:
# /tmp/ipykernel_642365/1422499183.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['val']=df_filtered['type'].apply(lambda x: x.split('_')[1])
# /tmp/ipykernel_642365/1422499183.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['type']=df_filtered['type'].apply(lambda x: x.split('_')[0])
# /tmp/ipykernel_642365/1422499183.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['csv']=df_filtered.apply(lambda row: os.path.join(os.path.dirname(NO_ACTI_CSV), 'figures', f"{row['bundle']}_{row['metric']}_{row['val']}_{row['type']}_{'corrected' if 'group' in row['type'] else "partial"}.csv"), axis=1)
# /tmp/ipykernel_642365/1422499183.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['png']=df_filtered.apply(lambda row: os.path.join(os.path.dirname(NO_ACTI_CSV), 'figures', f"{row['bundle']}_{row['metric']}_{row['val']}_{row['type']}_{'corrected' if 'group' in row['type'] else "partial"}.png"), axis=1)

# %%
ACTI_CSV = "/data/ndecaux/report_actimetry_calcarine/summary_results.csv"
df_acti=pd.read_csv(ACTI_CSV)
filters_acti={
    "fronto_limbiques": df_acti['bundle'].isin(fronto_limbiques),
    "emotions": df_acti['bundle'].isin(emotions),
    "moteurs": df_acti['bundle'].isin(moteurs),
    "renaud_dep_controls": df_acti['bundle'].isin(renaud_dep_controls),
    "renaud_apathy": df_acti['bundle'].isin(renaud_apathy),
    "significant": df_acti['n_sig_corrected'] > 0,
    "all_subs": df_acti['removed_subjects']<2,
    "all_points": df_acti['removed_points']<4,
    "metric": df_acti['metric'].isin(['FA','IFW','IRF']),
    "min_r": df_acti['max_abs_r_partial'] > 0.6
}
final_filter_acti = filters_acti["significant"] & filters_acti["all_subs"] & filters_acti["all_points"] & filters_acti["metric"] & (filters_acti["emotions"] | filters_acti["moteurs"] | filters_acti["fronto_limbiques"])
df_acti_filtered = df_acti[final_filter_acti]
df_acti_filtered['val']=df_acti_filtered['type'].apply(lambda x: '_'.join(x.split('_')[1:]))
df_acti_filtered['type']=df_acti_filtered['type'].apply(lambda x: x.split('_')[0])
df_acti_filtered['csv']=df_acti_filtered.apply(lambda row: os.path.join(os.path.dirname(ACTI_CSV), 'figures', f"{row['bundle']}_{row['metric']}_{row['val']}_{row['type']}_{'corrected' if 'group' in row['type'] else "partial"}.csv"), axis=1)
df_acti_filtered['png']=df_acti_filtered.apply(lambda row: os.path.join(os.path.dirname(ACTI_CSV), 'figures', f"{row['bundle']}_{row['metric']}_{row['val']}_{row['type']}_{'corrected' if 'group' in row['type'] else "partial"}.png"), axis=1)
df_acti_filtered
# Out:
# /tmp/ipykernel_642365/3385214335.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acti_filtered['val']=df_acti_filtered['type'].apply(lambda x: '_'.join(x.split('_')[1:]))
# /tmp/ipykernel_642365/3385214335.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acti_filtered['type']=df_acti_filtered['type'].apply(lambda x: x.split('_')[0])
# /tmp/ipykernel_642365/3385214335.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acti_filtered['csv']=df_acti_filtered.apply(lambda row: os.path.join(os.path.dirname(ACTI_CSV), 'figures', f"{row['bundle']}_{row['metric']}_{row['val']}_{row['type']}_{'corrected' if 'group' in row['type'] else "partial"}.csv"), axis=1)
# /tmp/ipykernel_642365/3385214335.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acti_filtered['png']=df_acti_filtered.apply(lambda row: os.path.join(os.path.dirname(ACTI_CSV), 'figures', f"{row['bundle']}_{row['metric']}_{row['val']}_{row['type']}_{'corrected' if 'group' in row['type'] else "partial"}.png"), axis=1)
#             bundle metric  type  n_sig_raw  n_sig_corrected     min_p_raw  \
# 247    STPREMright     FA  corr          1                1  1.064237e-03
# 291     STPRECleft    IRF  corr          0                1  1.664228e-02
# 315     TPOSTCleft    IRF  corr          1                1  7.905573e-04
# 326      TPREMleft    IFW  corr          1                1  1.270762e-07
# 422      TPREFleft    IFW  corr          1                1  4.123166e-04
# ...            ...    ...   ...        ...              ...           ...
# 77036   STPREFleft    IFW  corr          1                1  1.195763e-03
# 77042   TPREFright    IFW  corr          1                1  2.786134e-03
# 77078    TPRECleft    IFW  corr          1                1  2.123242e-03
# 77090      UFright    IFW  corr          1                1  6.395883e-04
# 77102    TPREFleft    IFW  corr          1                1  2.730962e-03
#
#        min_p_corrected  max_abs_r_raw  max_abs_r_partial  removed_subjects  \
# 247       1.128433e-03       0.433315           0.431338                 0
# 291       2.139664e-03       0.324571           0.408927                 0
# 315       3.008007e-03       0.443172           0.396343                 0
# 326       2.160077e-07       0.646709           0.637603                 0
# 422       5.742270e-04       0.463777           0.453453                 0
# ...                ...            ...                ...               ...
# 77036     9.258404e-04       0.429369           0.437971                 0
# 77042     1.759418e-03       0.399216           0.415944                 0
# 77078     3.218601e-03       0.409206           0.393785                 0
# 77090     5.102526e-04       0.450023           0.457172                 0
# 77102     3.772194e-03       0.399962           0.387705                 0
#
#        removed_points  clusterFWE_raw  clusterFWE_corrected  \
# 247                 2            11.0                  10.0
# 291                 2            11.0                  10.0
# 315                 2             9.0                   8.0
# 326                 2            11.0                  10.0
# 422                 2            11.0                  12.0
# ...               ...             ...                   ...
# 77036               2            13.0                  12.0
# 77042               2             9.0                   9.0
# 77078               2            11.0                  11.0
# 77090               2             7.0                   7.0
# 77102               2             9.0                   9.0
#
#                       val                                                csv  \
# 247    inactivity_mean_3d  /data/ndecaux/report_actimetry_calcarine/figur...
# 291    inactivity_mean_3d  /data/ndecaux/report_actimetry_calcarine/figur...
# 315    inactivity_mean_3d  /data/ndecaux/report_actimetry_calcarine/figur...
# 326    inactivity_mean_3d  /data/ndecaux/report_actimetry_calcarine/figur...
# 422    inactivity_mean_3d  /data/ndecaux/report_actimetry_calcarine/figur...
# ...                   ...                                                ...
# 77036  oadl_fft_max_12h_6  /data/ndecaux/report_actimetry_calcarine/figur...
# 77042  oadl_fft_max_12h_6  /data/ndecaux/report_actimetry_calcarine/figur...
# 77078  oadl_fft_max_12h_6  /data/ndecaux/report_actimetry_calcarine/figur...
# 77090  oadl_fft_max_12h_6  /data/ndecaux/report_actimetry_calcarine/figur...
# 77102  oadl_fft_max_12h_6  /data/ndecaux/report_actimetry_calcarine/figur...
#
#                                                      png
# 247    /data/ndecaux/report_actimetry_calcarine/figur...
# 291    /data/ndecaux/report_actimetry_calcarine/figur...
# 315    /data/ndecaux/report_actimetry_calcarine/figur...
# 326    /data/ndecaux/report_actimetry_calcarine/figur...
# 422    /data/ndecaux/report_actimetry_calcarine/figur...
# ...                                                  ...
# 77036  /data/ndecaux/report_actimetry_calcarine/figur...
# 77042  /data/ndecaux/report_actimetry_calcarine/figur...
# 77078  /data/ndecaux/report_actimetry_calcarine/figur...
# 77090  /data/ndecaux/report_actimetry_calcarine/figur...
# 77102  /data/ndecaux/report_actimetry_calcarine/figur...
#
# [717 rows x 16 columns]

# %%
df_group = df_filtered[df_filtered['val'] == 'group']
df_psycho = df_filtered[df_filtered['type'].str.contains('corr', na=False)]
df_apathy = df_filtered[df_filtered['val'] == 'apathy']

#Get the bundles that exists in df_group, df_psycho, df_apathy and df_acti_filtered
common_bundles = set(df_acti_filtered['bundle']).intersection(set(df_psycho['bundle'])).intersection(set(df_apathy['bundle']))
print('set of group bundles:', set(df_group['bundle']))
print('set of psycho bundles:', set(df_psycho['bundle']))
print('set of apathy bundles:', set(df_apathy['bundle']))
print('set of acti bundles:', set(df_acti_filtered['bundle']))
print('common bundles:', common_bundles)
common_bundles
# Out:
# set of group bundles: {'TPOSTCleft', 'STPREFleft', 'TPREMright', 'STPOSTCleft', 'STPREMleft', 'STPRECleft', 'UFleft', 'TPRECleft', 'STFOleft', 'CSTleft', 'FPTleft', 'CC4', 'STFOright', 'STPOSTCright'}
# set of psycho bundles: {'TPOSTCleft', 'STPREFright', 'STPREFleft', 'FPTright', 'STPOSTCleft', 'STPREMleft', 'STPRECleft', 'TPREFright', 'UFleft', 'TPRECleft', 'STFOleft', 'STFOright', 'STPOSTCright', 'STPRECright'}
# set of apathy bundles: {'CSTright', 'STPOSTCleft'}
# set of acti bundles: {'STPREFright', 'STPREFleft', 'TPRECright', 'STPREMright', 'STPOSTCleft', 'TPREFright', 'UFleft', 'STFOleft', 'FPTleft', 'ATRleft', 'CSTleft', 'SCPleft', 'TPOSTCright', 'CC4', 'STPOSTCright', 'STPRECright', 'TPOSTCleft', 'ICPleft', 'ICPright', 'FPTright', 'CSTright', 'STPREMleft', 'CC3', 'TPRECleft', 'TPREMleft', 'UFright', 'TPREMright', 'STPRECleft', 'MCP', 'STFOright', 'TPREFleft'}
# common bundles: {'STPOSTCleft'}
# {'STPOSTCleft'}

# %%
chosen_one = list(common_bundles)
#All bundles 
chosen_one = moteurs + emotions + fronto_limbiques
df_group = df_group[df_group['bundle'].isin(chosen_one)]
df_psycho = df_psycho[df_psycho['bundle'].isin(chosen_one)]
df_apathy = df_apathy[df_apathy['bundle'].isin(chosen_one)]
df_acti_filtered = df_acti_filtered[df_acti_filtered['bundle'].isin(chosen_one)]
#Concatenate all dataframes
df_final = pd.concat([df_group, df_psycho, df_apathy, df_acti_filtered], ignore_index=True)
#Copy all csv and png to a new folder
output_folder = '/home/ndecaux/NAS_EMPENN/share/projects/actidep/prez_seminaire'
os.makedirs(output_folder, exist_ok=True)
for _, row in df_final.iterrows():
    os.system(f'cp {row["csv"]} {output_folder}/')
    os.system(f'cp {row["png"]} {output_folder}/')

df_final
# Out:
#          bundle metric   type  n_sig_raw  n_sig_corrected  min_p_raw  \
# 0      STFOleft     FA  group          2                2   0.000257
# 1     STFOright     FA  group          2                1   0.007571
# 2    TPREMright     FA  group          0                1   0.005899
# 3    STPREFleft     FA  group          1                1   0.006054
# 4        UFleft     FA  group          1                1   0.003240
# ..          ...    ...    ...        ...              ...        ...
# 755  STPREFleft    IFW   corr          1                1   0.001196
# 756  TPREFright    IFW   corr          1                1   0.002786
# 757   TPRECleft    IFW   corr          1                1   0.002123
# 758     UFright    IFW   corr          1                1   0.000640
# 759   TPREFleft    IFW   corr          1                1   0.002731
#
#      min_p_corrected  max_abs_r_raw  max_abs_r_partial  removed_subjects  \
# 0           0.000378            NaN                NaN                 0
# 1           0.005636            NaN                NaN                 0
# 2           0.002610            NaN                NaN                 0
# 3           0.005968            NaN                NaN                 0
# 4           0.001302            NaN                NaN                 1
# ..               ...            ...                ...               ...
# 755         0.000926       0.429369           0.437971                 0
# 756         0.001759       0.399216           0.415944                 0
# 757         0.003219       0.409206           0.393785                 0
# 758         0.000510       0.450023           0.457172                 0
# 759         0.003772       0.399962           0.387705                 0
#
#      removed_points  clusterFWE_raw  clusterFWE_corrected                 val  \
# 0                 2             8.0                   9.0               group
# 1                 2             8.0                   8.0               group
# 2                 2             7.0                   6.0               group
# 3                 2            10.0                  10.0               group
# 4                 2             6.0                   6.0               group
# ..              ...             ...                   ...                 ...
# 755               2            13.0                  12.0  oadl_fft_max_12h_6
# 756               2             9.0                   9.0  oadl_fft_max_12h_6
# 757               2            11.0                  11.0  oadl_fft_max_12h_6
# 758               2             7.0                   7.0  oadl_fft_max_12h_6
# 759               2             9.0                   9.0  oadl_fft_max_12h_6
#
#                                                    csv  \
# 0    /home/ndecaux/report_optimized_no_actimetry_cl...
# 1    /home/ndecaux/report_optimized_no_actimetry_cl...
# 2    /home/ndecaux/report_optimized_no_actimetry_cl...
# 3    /home/ndecaux/report_optimized_no_actimetry_cl...
# 4    /home/ndecaux/report_optimized_no_actimetry_cl...
# ..                                                 ...
# 755  /data/ndecaux/report_actimetry_calcarine/figur...
# 756  /data/ndecaux/report_actimetry_calcarine/figur...
# 757  /data/ndecaux/report_actimetry_calcarine/figur...
# 758  /data/ndecaux/report_actimetry_calcarine/figur...
# 759  /data/ndecaux/report_actimetry_calcarine/figur...
#
#                                                    png
# 0    /home/ndecaux/report_optimized_no_actimetry_cl...
# 1    /home/ndecaux/report_optimized_no_actimetry_cl...
# 2    /home/ndecaux/report_optimized_no_actimetry_cl...
# 3    /home/ndecaux/report_optimized_no_actimetry_cl...
# 4    /home/ndecaux/report_optimized_no_actimetry_cl...
# ..                                                 ...
# 755  /data/ndecaux/report_actimetry_calcarine/figur...
# 756  /data/ndecaux/report_actimetry_calcarine/figur...
# 757  /data/ndecaux/report_actimetry_calcarine/figur...
# 758  /data/ndecaux/report_actimetry_calcarine/figur...
# 759  /data/ndecaux/report_actimetry_calcarine/figur...
#
# [760 rows x 16 columns]

# %%
#Get rows that have the same bundle and metric in every sub df
import numpy as np
unique_group = df_group[['bundle','metric']].drop_duplicates()
unique_psycho = df_psycho[['bundle','metric']].drop_duplicates()
unique_apathy = df_apathy[['bundle','metric']].drop_duplicates()
unique_acti = df_acti_filtered[['bundle','metric']].drop_duplicates()
common_bundles_metrics = pd.merge(pd.merge(pd.merge(unique_group, unique_psycho, on=['bundle','metric']), unique_apathy, on=['bundle','metric']), unique_acti, on=['bundle','metric'])
common_bundles_metrics
# Out:
# Empty DataFrame
# Columns: [bundle, metric]
# Index: []

# %%
chosen_csv = "/home/ndecaux/NAS_EMPENN/share/projects/actidep/prez_seminaire/STPREMleft_FA_ami_corr_partial.csv"
profile = pd.read_csv(chosen_csv)
profile=profile[profile['sig_afq']]
model = "/home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/hcp_association_50pts/sub-01002/tracto/sub-01002_bundle-STPREMleft_desc-associations_model-MCM_space-HCP_tracto.vtk"

import pyvista
import vtk

#Load the tract model
mesh = pyvista.read(model)
# Build mapping from AFQ point index to r value
p2r = dict(zip(profile['point'].astype(int), profile['r'].astype(float)))

# Fetch mesh point indices and convert to int
if 'point_index' not in mesh.point_data:
    raise KeyError("Mesh is missing 'point_index' point-data array.")
pi = np.asarray(mesh.point_data['point_index']).astype(int)
print(p2r)
# Create r array for all mesh points (default 0 when missing)
r_values = np.array([p2r.get(i, 0.0) for i in pi], dtype=float)
# Attach as point data
mesh.point_data['r'] = r_values

#Save as vtk
output_vtk = chosen_csv.replace('.csv', '.vtk')
mesh.save(output_vtk)
# Out:
# {30: 0.3617676977379898, 31: 0.3622788983478815, 32: 0.3729051467652241, 33: 0.3996985407416196, 34: 0.4727139859726982, 35: 0.5108806482860487, 36: 0.5381964420036282, 37: 0.5654987013313211, 38: 0.5721668024021739, 39: 0.5384551935852173, 40: 0.6067473203538131, 41: 0.593751185148401, 42: 0.5931073324616287, 43: 0.5919142739153945, 44: 0.5491057137198521, 45: 0.4742442168919772, 46: 0.3920388132049268}

# %%
from tractviewer import TractViewer
viewer = TractViewer()
viewer.add_dataset(
    "/home/ndecaux/Code/Data/Atlas/atlas_anat.nii.gz",
    {
        "display_array": "intensity",
        "cmap": "gray",
        "clim": (200, 800),
        "opacity": 0.1,
        "ambient": 0.6,
        "diffuse": 0.8,
        "specular": 0.1,
        "scalar_bar": False,
        "name": "anatomy",
        "style": "surface",
    }
).add_dataset(
    output_vtk,
    {
        "display_array": "r",
        "cmap": "coolwarm",
        "clim": (-1, 1),
        "opacity": 1.0,
        "ambient": 0.3,
        "diffuse": 0.6,
        "specular": 0.5,
        "scalar_bar": True,
        "name": "STPREMleft_FA_ami_corr_partial",
        "tube_radius": 1.0,
    }
)

viewer.record_rotation(
    "/home/ndecaux/NAS_EMPENN/share/projects/actidep/prez_seminaire/STPREMleft_FA_ami_corr_partial.gif",
    n_frames=240,      # nombre d'images
    step=1.5,          # incrément azimut
    elevation=0.0,     # mettre p.ex 10 pour basculer en 1ère moitié puis -10
    fps=10,
    quality=9,         # (imageio) 0-10
    crf=18,            # (si pas de bitrate)
    supersample=2,     # rendu interne 2x puis compressé (plus net)
    window_size=(960, 720),
)
# Out:
# /home/ndecaux/Code/TractViewer/tractviewer/core.py:58: UserWarning: Aucun DISPLAY détecté -> passage en mode off_screen.
#   warnings.warn("Aucun DISPLAY détecté -> passage en mode off_screen.")
# Isosurface extraite (marching_cubes) à 0.200 dans atlas_anat.nii.gz
# '/home/ndecaux/NAS_EMPENN/share/projects/actidep/prez_seminaire/STPREMleft_FA_ami_corr_partial.gif'
