# %%
import os
import sys
import glob
import pathlib
import shutil
root_dir = "/home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults"
base_dir = os.path.dirname(root_dir) # Get the parent directory of root_dir

sub_list = glob.glob(os.path.join(root_dir, "sub-*"))
sub_list.sort()

#For each subject folder, get the folder where files that ends with _cleaned.trk are stored

good_dir={}
for sub in sub_list:
    #Get the list of all folders that contain files ending with _cleaned.trk
    print(os.path.join(sub, "*", "*_cleaned.trk"))
    folder_list = glob.glob(os.path.join(sub, "*", "*", "*_cleaned.trk"))
    folder_list.sort()
    sub_id = os.path.basename(sub)

    #For each folder, get the name of the folder
    if os.path.exists(
            os.path.join(base_dir, "bids", "derivatives", "bundle_seg",
                         sub_id)):
        print('Skipping subject', sub_id)
        continue
    for folder in folder_list:
        #Get the name of the folder
        folder_name = os.path.basename(os.path.dirname(folder))
        #Get the name of the file
        file_name = os.path.basename(folder)
        #Get the parent folder
        parent_folder = os.path.basename(
            os.path.dirname(os.path.dirname(folder)))
        #Get the name of the subject
        target_dir = os.path.join(sub, parent_folder, folder_name)
        good_dir[sub_id] = target_dir

        #Extract in the file what's between summed_ and _cleaned
        bundle_name = file_name.split("_cleaned")[0].split(
            "summed_")[1].replace("_", "")

        #The target name shoudl be sub-<sub_id>_bundle-<bundle_name>_desc-cleaned_tracto.trk
        target_name = f"{sub_id}_bundle-{bundle_name}_desc-cleaned_tracto.trk"

        #Target path is /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-<sub_id>/tracto/sub-<sub_id>_bundle-<bundle_name>_desc-cleaned_tracto.trk

        target_path = os.path.join(base_dir, "bids", "derivatives",
                                   "bundle_seg", sub_id, "tracto", target_name)
        #Create the target directory if it doesn't exist
        os.makedirs(os.path.dirname(target_path), exist_ok=True)
        #Copy the file to the target directory

        shutil.copy(folder, target_path)

        print(f"Copying {folder} to {target_path}")

        #Print the name of the subject, folder and file
        # print(f"{sub_name} {folder_name} {file_name}")
        #

print(good_dir)
# Out:
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01001/*/*_cleaned.trk
# Skipping subject sub-01001
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/*/*_cleaned.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_AF_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-AFleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_AF_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-AFright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ATR_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-ATRleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ATR_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-ATRright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_CA_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-CA_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_CC_1_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-CC1_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_CC_2_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-CC2_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_CC_3_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-CC3_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_CC_7_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-CC7_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_CG_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-CGleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_CG_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-CGright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_CST_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-CSTleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_CST_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-CSTright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_FPT_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-FPTleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_FPT_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-FPTright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_FX_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-FXleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_FX_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-FXright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ICP_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-ICPleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ICP_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-ICPright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_IFO_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-IFOleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_IFO_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-IFOright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ILF_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-ILFleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ILF_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-ILFright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_MCP_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-MCP_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_MLF_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-MLFleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_MLF_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-MLFright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_OR_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-ORleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_OR_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-ORright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_POPT_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-POPTleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_POPT_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-POPTright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_SCP_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-SCPleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_SCP_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-SCPright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_SLF_III_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-SLFIIIleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_SLF_III_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-SLFIIIright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_SLF_II_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-SLFIIleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_SLF_II_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-SLFIIright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_SLF_I_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-SLFIleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_SLF_I_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-SLFIright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_STR_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STRleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_STR_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STRright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_FO_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STFOleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_FO_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STFOright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_OCC_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STOCCleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_OCC_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STOCCright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_PAR_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STPARleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_PAR_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STPARright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_POSTC_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STPOSTCleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_POSTC_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STPOSTCright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_PREC_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STPRECleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_PREC_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STPRECright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_PREF_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STPREFleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_PREF_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STPREFright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_PREM_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STPREMleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_ST_PREM_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-STPREMright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_T_OCC_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-TOCCleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_T_OCC_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-TOCCright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_T_PAR_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-TPARleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_T_PAR_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-TPARright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_T_POSTC_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-TPOSTCleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_T_POSTC_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-TPOSTCright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_T_PREC_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-TPRECleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_T_PREC_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-TPRECright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_T_PREF_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-TPREFleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_T_PREF_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-TPREFright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_T_PREM_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-TPREMleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_T_PREM_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-TPREMright_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_UF_left_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-UFleft_desc-cleaned_tracto.trk
# Copying /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71/S1__summed_UF_right_cleaned.trk to /home/ndecaux/NAS_EMPENN/share/projects/actidep/bids/derivatives/bundle_seg/sub-01002/tracto/sub-01002_bundle-UFright_desc-cleaned_tracto.trk
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01006/*/*_cleaned.trk
# Skipping subject sub-01006
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01007/*/*_cleaned.trk
# Skipping subject sub-01007
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01008/*/*_cleaned.trk
# Skipping subject sub-01008
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01009/*/*_cleaned.trk
# Skipping subject sub-01009
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01010/*/*_cleaned.trk
# Skipping subject sub-01010
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01012/*/*_cleaned.trk
# Skipping subject sub-01012
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01013/*/*_cleaned.trk
# Skipping subject sub-01013
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01014/*/*_cleaned.trk
# Skipping subject sub-01014
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01015/*/*_cleaned.trk
# Skipping subject sub-01015
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01016/*/*_cleaned.trk
# Skipping subject sub-01016
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01017/*/*_cleaned.trk
# Skipping subject sub-01017
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01018/*/*_cleaned.trk
# Skipping subject sub-01018
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01019/*/*_cleaned.trk
# Skipping subject sub-01019
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01020/*/*_cleaned.trk
# Skipping subject sub-01020
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01021/*/*_cleaned.trk
# Skipping subject sub-01021
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01022/*/*_cleaned.trk
# Skipping subject sub-01022
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01023/*/*_cleaned.trk
# Skipping subject sub-01023
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01025/*/*_cleaned.trk
# Skipping subject sub-01025
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01026/*/*_cleaned.trk
# Skipping subject sub-01026
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01027/*/*_cleaned.trk
# Skipping subject sub-01027
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01028/*/*_cleaned.trk
# Skipping subject sub-01028
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01029/*/*_cleaned.trk
# Skipping subject sub-01029
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01030/*/*_cleaned.trk
# Skipping subject sub-01030
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01031/*/*_cleaned.trk
# Skipping subject sub-01031
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01032/*/*_cleaned.trk
# Skipping subject sub-01032
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01033/*/*_cleaned.trk
# Skipping subject sub-01033
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01034/*/*_cleaned.trk
# Skipping subject sub-01034
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01035/*/*_cleaned.trk
# Skipping subject sub-01035
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01036/*/*_cleaned.trk
# Skipping subject sub-01036
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01037/*/*_cleaned.trk
# Skipping subject sub-01037
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01038/*/*_cleaned.trk
# Skipping subject sub-01038
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01039/*/*_cleaned.trk
# Skipping subject sub-01039
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01040/*/*_cleaned.trk
# Skipping subject sub-01040
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01041/*/*_cleaned.trk
# Skipping subject sub-01041
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01042/*/*_cleaned.trk
# Skipping subject sub-01042
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01043/*/*_cleaned.trk
# Skipping subject sub-01043
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01044/*/*_cleaned.trk
# Skipping subject sub-01044
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03002/*/*_cleaned.trk
# Skipping subject sub-03002
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03003/*/*_cleaned.trk
# Skipping subject sub-03003
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03004/*/*_cleaned.trk
# Skipping subject sub-03004
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03005/*/*_cleaned.trk
# Skipping subject sub-03005
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03008/*/*_cleaned.trk
# Skipping subject sub-03008
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03009/*/*_cleaned.trk
# Skipping subject sub-03009
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03010/*/*_cleaned.trk
# Skipping subject sub-03010
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03011/*/*_cleaned.trk
# Skipping subject sub-03011
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03012/*/*_cleaned.trk
# Skipping subject sub-03012
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03013/*/*_cleaned.trk
# Skipping subject sub-03013
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03014/*/*_cleaned.trk
# Skipping subject sub-03014
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03015/*/*_cleaned.trk
# Skipping subject sub-03015
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03016/*/*_cleaned.trk
# Skipping subject sub-03016
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03017/*/*_cleaned.trk
# Skipping subject sub-03017
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03018/*/*_cleaned.trk
# Skipping subject sub-03018
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03019/*/*_cleaned.trk
# Skipping subject sub-03019
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03020/*/*_cleaned.trk
# Skipping subject sub-03020
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03021/*/*_cleaned.trk
# Skipping subject sub-03021
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03022/*/*_cleaned.trk
# Skipping subject sub-03022
# /home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-03024/*/*_cleaned.trk
# Skipping subject sub-03024
# {'sub-01002': '/home/ndecaux/NAS_EMPENN/share/projects/actidep/BundleSegResults/sub-01002/97/4db85bbba68faeec323e8c189a8b71'}
