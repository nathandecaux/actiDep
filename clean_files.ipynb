# %%
from actiDep.data.loader import Subject,Actidep
import os
import pandas as pd
ds = Actidep('/home/ndecaux/NAS_EMPENN/share/projects/amynet/bids')
# fa=ds.get_global(pipeline='anima_preproc',metric='FA')
# dti=ds.get_global(pipeline='anima_preproc',model='DTI',metric=None)
# brain_mask=ds.get_global(pipeline='anima_preproc',suffix='mask',label='brain',extension='.nii.gz',model=None,datatype='dwi')
# print(len(fa))
# print(len(dti))
# print(len(preproc_dwi))
# wrong_T1=ds.get_global(pipeline='anima_preproc',suffix='T1w',label=None)
# print([x.path for x in wrong_T1])

# #Remove all wrong T1 files
# for f in wrong_T1:
#     print(f'Removing {f.path}')
#     os.remove(f.path)

# for m in brain_mask:
#     m.update_entities(space='B0')
# print([x.path for x in brain_mask])

# bundleseg_tracto=ds.get_global(suffix='tracto',label='brain',extension='trk',datatype='tracto',pipeline='bundle_seg_nonrigid')
bundleseg_tracto=ds.get_global(datatype='atlas',suffix='bundle-')

df=pd.concat([b.df for b in bundleseg_tracto])
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 26
#       5 # fa=ds.get_global(pipeline='anima_preproc',metric='FA')
#       6 # dti=ds.get_global(pipeline='anima_preproc',model='DTI',metric=None)
#       7 # brain_mask=ds.get_global(pipeline='anima_preproc',suffix='mask',label='brain',extension='.nii.gz',model=None,datatype='dwi')
#    (...)
#      22
#      23 # bundleseg_tracto=ds.get_global(suffix='tracto',label='brain',extension='trk',datatype='tracto',pipeline='bundle_seg_nonrigid')
#      24 bundleseg_tracto=ds.get_global(datatype='atlas',suffix='bundle-')
# ---> 26 df=pd.concat([b.df for b in bundleseg_tracto])
#      27 df
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/reshape/concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/reshape/concat.py:445, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     442 self.verify_integrity = verify_integrity
#     443 self.copy = copy
# --> 445 objs, keys = self._clean_keys_and_objs(objs, keys)
#     447 # figure out what our result ndim is going to be
#     448 ndims = self._get_ndims(objs)
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/reshape/concat.py:507, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     504     objs_list = list(objs)
#     506 if len(objs_list) == 0:
# --> 507     raise ValueError("No objects to concatenate")
#     509 if keys is None:
#     510     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %%
import os
from glob import glob
import shutil  
wrong_dirs = glob('/home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/*/atlas/sub-*_algo-ifod2_atlas-HCP_bundle-')

#Remove all wrong directories
for d in wrong_dirs:
    print(f'Removing {d}')
    shutil.rmtree(d)
# Out:
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-06/atlas/sub-06_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-26/atlas/sub-26_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-21/atlas/sub-21_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-16/atlas/sub-16_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-23/atlas/sub-23_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-01622/atlas/sub-01622_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-01616/atlas/sub-01616_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-19/atlas/sub-19_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-01001/atlas/sub-01001_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-12/atlas/sub-12_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-08/atlas/sub-08_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-25/atlas/sub-25_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-07/atlas/sub-07_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-24/atlas/sub-24_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-10/atlas/sub-10_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-13/atlas/sub-13_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-01625/atlas/sub-01625_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-18/atlas/sub-18_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-22/atlas/sub-22_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-01619/atlas/sub-01619_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-01618/atlas/sub-01618_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-17/atlas/sub-17_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-20/atlas/sub-20_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-01623/atlas/sub-01623_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-11/atlas/sub-11_algo-ifod2_atlas-HCP_bundle-
# Removing /home/ndecaux/NAS_EMPENN/share/projects/amynet/bids/derivatives/bundle_seg_nonrigid/sub-09/atlas/sub-09_algo-ifod2_atlas-HCP_bundle-
